# %% [markdown]
# # **Control Assignment**
#
# ### **Required task**
#
#
# 1. Plot the step response for the uncontrolled system (already given as an example)
# 2. Design a P controller $f = K_p \cdot error$ which render the system critically damped, plot the step response of the system.
#
# Please check the following document for coding with python-control package:
# https://python-control.readthedocs.io/en/0.10.0/

# %% [markdown]
# ## **Initial Setup**

# %% [markdown]
# First, install the `control` package in Python.

# %%
# !pip install control
# Out:
# Requirement already satisfied: control in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from control) (2.2.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from control) (1.15.2)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from control) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6->control) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6->control) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6->control) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6->control) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6->control) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6->control) (11.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6->control) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6->control) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\reece\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->control) (1.17.0)

# %% [markdown]
# ## **Details**

# %% [markdown]
# Import the `control`, `numpy` and `matplotlib` packages.

# %%
import control as co
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Defining the uncontrolled system**

# %% [markdown]
# Define a transfer function $G_1(s)=\dfrac{1}{4s^2+2s+0.1}$ with

# %%
G1 = co.tf([1], [4, 2, 0.1])
print(G1)
# Out:
# <TransferFunction>: sys[7]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#         1
# -----------------
# 4 s^2 + 2 s + 0.1

# %% [markdown]
# Step response

# %%
t = np.linspace(0, 200, 200) # time is taken from 0s to 10s
_, y = co.step_response(G1, t) # calculate the step response of G1

plt.plot(t, y) # plot the response
plt.xlabel('time (s)') # labels
plt.ylabel('amplitude') # labels
plt.title('step response') # title
plt.grid() # grid

# %% [markdown]
# ### **Please implement your controller and plot the step response below**

# %%
Kp = 0.15

C = co.tf([Kp], [1]) # proportional controller

G2 = co.feedback(C * G1, 1)

_, y = co.step_response(G2, t) # calculate the step response of G2

plt.plot(t, y) # plot the response
plt.xlabel('time (s)') # labels
plt.ylabel('amplitude') # labels
plt.title('step response') # title
plt.grid() # grid
